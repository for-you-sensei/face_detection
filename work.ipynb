# %%
# %%cmd
# pip install "C:\Users\marus\Desktop\face_det\dlib-19.24.1-cp311-cp311-win_amd64.whl"
# Out:
# Microsoft Windows [Version 10.0.22621.3880]
# (c) Microsoft Corporation. All rights reserved.
#
# (C:\Users\marus\miniconda3) c:\Users\marus\Desktop\face_det>pip install "C:\Users\marus\Desktop\face_det\dlib-19.24.1-cp311-cp311-win_amd64.whl"
# Processing c:\users\marus\desktop\face_det\dlib-19.24.1-cp311-cp311-win_amd64.whl
# Installing collected packages: dlib
# Successfully installed dlib-19.24.1
#
# (C:\Users\marus\miniconda3) c:\Users\marus\Desktop\face_det>

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\marus\miniconda3\lib\site-packages (4.8.1.78)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\marus\miniconda3\lib\site-packages (from opencv-python) (1.26.2)

# %%
import cv2

# %%
# %%cmd
# pip install face_recognition
# Out:
# Microsoft Windows [Version 10.0.22621.3880]
# (c) Microsoft Corporation. All rights reserved.
#
# (C:\Users\marus\miniconda3) c:\Users\marus\Desktop\face_det>pip install face_recognition
# Collecting face_recognition
#   Using cached face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Collecting face-recognition-models>=0.3.0 (from face_recognition)
#   Using cached face_recognition_models-0.3.0-py2.py3-none-any.whl
# Collecting Click>=6.0 (from face_recognition)
#   Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Requirement already satisfied: dlib>=19.7 in c:\users\marus\miniconda3\lib\site-packages (from face_recognition) (19.24.1)
# Requirement already satisfied: numpy in c:\users\marus\miniconda3\lib\site-packages (from face_recognition) (1.26.2)
# Requirement already satisfied: Pillow in c:\users\marus\miniconda3\lib\site-packages (from face_recognition) (10.2.0)
# Requirement already satisfied: colorama in c:\users\marus\miniconda3\lib\site-packages (from Click>=6.0->face_recognition) (0.4.6)
# Installing collected packages: face-recognition-models, Click, face_recognition
# Successfully installed Click-8.1.7 face-recognition-models-0.3.0 face_recognition-1.3.0
#
# (C:\Users\marus\miniconda3) c:\Users\marus\Desktop\face_det>

# %%
# %%cmd
# pip install cmake
# Out:
# Microsoft Windows [Version 10.0.22621.3880]
# (c) Microsoft Corporation. All rights reserved.
#
# (C:\Users\marus\miniconda3) c:\Users\marus\Desktop\face_det>pip install cmake
# Collecting cmake
#   Downloading cmake-3.30.1-py3-none-win_amd64.whl (35.7 MB)
#      ---------------------------------------- 35.7/35.7 MB 1.4 MB/s eta 0:00:00
# Installing collected packages: cmake
# Successfully installed cmake-3.30.1
#
# (C:\Users\marus\miniconda3) c:\Users\marus\Desktop\face_det>

# %%
# %%cmd
# python --version
# Out:
# Microsoft Windows [Version 10.0.22621.3880]
# (c) Microsoft Corporation. All rights reserved.
#
# (C:\Users\marus\miniconda3) c:\Users\marus\Desktop\face_det>python --version
# Python 3.11.4
#
# (C:\Users\marus\miniconda3) c:\Users\marus\Desktop\face_det>

# %%
import face_recognition

# %%
# %%cmd
# pip install deepface
# Out:
# Microsoft Windows [Version 10.0.22621.3880]
# (c) Microsoft Corporation. All rights reserved.
#
# (C:\Users\marus\miniconda3) c:\Users\marus\Desktop\face_det>pip install deepface
# Collecting deepface
#   Downloading deepface-0.0.92-py3-none-any.whl (105 kB)
#      ------------------------------------ 105.5/105.5 kB 509.6 kB/s eta 0:00:00
# Requirement already satisfied: requests>=2.27.1 in c:\users\marus\miniconda3\lib\site-packages (from deepface) (2.31.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\marus\miniconda3\lib\site-packages (from deepface) (1.26.2)
# Collecting pandas>=0.23.4 (from deepface)
#   Downloading pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
#      ---------------------------------------- 11.6/11.6 MB 5.2 MB/s eta 0:00:00
# Collecting gdown>=3.10.1 (from deepface)
#   Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\marus\miniconda3\lib\site-packages (from deepface) (4.65.0)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\marus\miniconda3\lib\site-packages (from deepface) (10.2.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\marus\miniconda3\lib\site-packages (from deepface) (4.8.1.78)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\marus\miniconda3\lib\site-packages (from deepface) (2.15.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\marus\miniconda3\lib\site-packages (from deepface) (2.15.0)
# Collecting Flask>=1.1.2 (from deepface)
#   Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#      -------------------------------------- 101.7/101.7 kB 3.0 MB/s eta 0:00:00
# Collecting mtcnn>=0.1.0 (from deepface)
#   Downloading mtcnn-0.1.1-py3-none-any.whl (2.3 MB)
#      ---------------------------------------- 2.3/2.3 MB 5.5 MB/s eta 0:00:00
# Collecting retina-face>=0.0.1 (from deepface)
#   Downloading retina_face-0.0.17-py3-none-any.whl (25 kB)
# Collecting fire>=0.4.0 (from deepface)
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ---------------------------------------- 88.4/88.4 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting gunicorn>=20.1.0 (from deepface)
#   Downloading gunicorn-22.0.0-py3-none-any.whl (84 kB)
#      ---------------------------------------- 84.4/84.4 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: six in c:\users\marus\miniconda3\lib\site-packages (from fire>=0.4.0->deepface) (1.16.0)
# Requirement already satisfied: termcolor in c:\users\marus\miniconda3\lib\site-packages (from fire>=0.4.0->deepface) (2.4.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\marus\miniconda3\lib\site-packages (from Flask>=1.1.2->deepface) (3.0.1)
# Collecting Jinja2>=3.1.2 (from Flask>=1.1.2->deepface)
#   Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#      -------------------------------------- 133.3/133.3 kB 7.7 MB/s eta 0:00:00
# Collecting itsdangerous>=2.1.2 (from Flask>=1.1.2->deepface)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: click>=8.1.3 in c:\users\marus\miniconda3\lib\site-packages (from Flask>=1.1.2->deepface) (8.1.7)
# Collecting blinker>=1.6.2 (from Flask>=1.1.2->deepface)
#   Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\marus\miniconda3\lib\site-packages (from gdown>=3.10.1->deepface) (4.12.2)
# Collecting filelock (from gdown>=3.10.1->deepface)
#   Downloading filelock-3.15.4-py3-none-any.whl (16 kB)
# Requirement already satisfied: packaging in c:\users\marus\miniconda3\lib\site-packages (from gunicorn>=20.1.0->deepface) (23.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\marus\miniconda3\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Collecting pytz>=2020.1 (from pandas>=0.23.4->deepface)
#   Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#      -------------------------------------- 505.5/505.5 kB 5.3 MB/s eta 0:00:00
# Collecting tzdata>=2022.7 (from pandas>=0.23.4->deepface)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      -------------------------------------- 345.4/345.4 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\marus\miniconda3\lib\site-packages (from requests>=2.27.1->deepface) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marus\miniconda3\lib\site-packages (from requests>=2.27.1->deepface) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\marus\miniconda3\lib\site-packages (from requests>=2.27.1->deepface) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marus\miniconda3\lib\site-packages (from requests>=2.27.1->deepface) (2023.11.17)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\marus\miniconda3\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\marus\miniconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\marus\miniconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\marus\miniconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\marus\miniconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\marus\miniconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\marus\miniconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\marus\miniconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\marus\miniconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\marus\miniconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\marus\miniconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (4.25.3)
# Requirement already satisfied: setuptools in c:\users\marus\miniconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (67.8.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\marus\miniconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\marus\miniconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\marus\miniconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\marus\miniconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\marus\miniconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\marus\miniconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (2.15.0)
# Requirement already satisfied: colorama in c:\users\marus\miniconda3\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\marus\miniconda3\lib\site-packages (from Jinja2>=3.1.2->Flask>=1.1.2->deepface) (2.1.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\marus\miniconda3\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\marus\miniconda3\lib\site-packages (from requests>=2.27.1->deepface) (1.7.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\marus\miniconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\marus\miniconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (2.26.2)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\marus\miniconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\marus\miniconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (3.5.2)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 (from tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface)
#   Using cached protobuf-4.23.4-cp310-abi3-win_amd64.whl (422 kB)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\marus\miniconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.7.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\marus\miniconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\marus\miniconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\marus\miniconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\marus\miniconda3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (1.3.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\marus\miniconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\marus\miniconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow>=1.9.0->deepface) (3.2.2)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117047 sha256=32d18277e22625c950acbad68deb5652c0ede741be15da52c7ba014861293dda
#   Stored in directory: c:\users\marus\appdata\local\pip\cache\wheels\6a\f3\0c\fa347dfa663f573462c6533d259c2c859e97e103d1ce21538f
# Successfully built fire
# Installing collected packages: pytz, tzdata, protobuf, Jinja2, itsdangerous, gunicorn, fire, filelock, blinker, pandas, mtcnn, Flask, gdown, retina-face, deepface
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Uninstalling protobuf-4.25.3:
#       Successfully uninstalled protobuf-4.25.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.14 requires protobuf<5,>=4.25.3, but you have protobuf 4.23.4 which is incompatible.
# Successfully installed Flask-3.0.3 Jinja2-3.1.4 blinker-1.8.2 deepface-0.0.92 filelock-3.15.4 fire-0.6.0 gdown-5.2.0 gunicorn-22.0.0 itsdangerous-2.2.0 mtcnn-0.1.1 pandas-2.2.2 protobuf-4.23.4 pytz-2024.1 retina-face-0.0.17 tzdata-2024.1
#
# (C:\Users\marus\miniconda3) c:\Users\marus\Desktop\face_det>

# %%
import dlib
import cv2
import numpy as np
import os
file_path = r"C:\Users\marus\Desktop\face_det\shape_predictor_68_face_landmarks.dat"
file2_path = r"C:\Users\marus\Desktop\face_det\dlib_face_recognition_resnet_model_v1.dat"
# Инициализируем детектор лиц dlib и предиктор

# %%
# img1_p= r"C:\Users\marus\Desktop\face_det\images\elontog'a\(1).jpg"
# im=cv2.imread(img1_p)
# img_rgb = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

# %%
import os
import cv2
import dlib
import numpy as np

detector = dlib.get_frontal_face_detector()
sp = dlib.shape_predictor(file_path)  # Replace with your shape predictor path
facerec = dlib.face_recognition_model_v1(file2_path)  # Replace with your face recognition model path

def process_images(directory):
    face_descriptors = {}
    for root, dirs, files in os.walk(directory):
        person_name = os.path.basename(root)
        if not files:
            continue
        
        face_descriptors[person_name] = []
        for file in files:
            if file.endswith('.jpg'):  # Adjust for other image formats if needed
                image_path = os.path.join(root, file)
                img = cv2.imread(image_path)
                img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                faces = detector(img_rgb, 1)

                for face in faces:
                    shape = sp(img_rgb, face)
                    face_descriptor = facerec.compute_face_descriptor(img_rgb, shape)
                    face_descriptors[person_name].append(np.array(face_descriptor))
    return face_descriptors

# Example usage:
path_images = r"C:\Users\marus\Desktop\face_det\images"
all_face_descriptors = process_images(path_images)

# Displaying face descriptors for each person
for person, descriptors in all_face_descriptors.items():
    print(f"Person: {person}, Number of descriptors: {len(descriptors)}")

# Example: calculate the average descriptor for each person
average_face_descriptors = {person: np.mean(descriptors, axis=0) for person, descriptors in all_face_descriptors.items()}
for person, avg_descriptor in average_face_descriptors.items():
    print(f"Average descriptor for {person}: {avg_descriptor}")
# Out:
# Person: Albert Einstein, Number of descriptors: 1
# Person: Elon Musk, Number of descriptors: 8
# Person: Jack Ma, Number of descriptors: 4
# Person: Jimmy, Number of descriptors: 4
  ,  0.11830369, -0.03162562, -0.12223708,\n        0.00881199,  0.00757837, -0.12502997,  0.17984199, -0.05877195,\n        0.26765686, -0.06480592, -0.25990059,  0.00293145, -0.00245007,\n        0.10220326, -0.16764996, -0.12236653, -0.04630451, -0.10402625,\n        0.0879598 ,  0.04357827,  0.02141383, -0.03535282, -0.13588567,\n       -0.30351535, -0.09329447, -0.07161755,  0.14670907, -0.0577109 ,\n        0.03824963,  0.04482699, -0.17881462, -0.08877658,  0.04839426,\n        0.03599884, -0.08727128, -0.08592322,  0.19784089, -0.03227839,\n       -0.17524379, -0.03957612,  0.02673773,  0.21561505,  0.13351845,\n        0.05427   ,  0.05311669, -0.12371703,  0.08317996, -0.21365569,\n        0.08360654,  0.16146901,  0.10068433,  0.04904282,  0.12242621,\n       -0.19798326,  0.00295193,  0.17950487, -0.14649992,  0.11615029,\n        0.10448374, -0.07355503,  0.00756507, -0.05376274,  0.1534581 ,\n        0.03445739, -0.05067624, -0.17319392,  0.21159056, -0.06578213,\n       -0.09580933,  0.14452019, -0.12592047, -0.15293926, -0.28688527,\n       -0.02152522,  0.46776354,  0.03087048, -0.16501909,  0.00151967,\n       -0.03839182,  0.00810295,  0.10803558,  0.06104746, -0.05776179,\n       -0.07234225, -0.13026039, -0.01561501,  0.20360871, -0.05258657,\n       -0.07630164,  0.18092691, -0.01218211,  0.01647697,  0.0426375 ,\n        0.07115268, -0.09459929,  0.0123012 , -0.11524039, -0.08152795,\n        0.05948926, -0.07209142, -0.04856162,  0.15230105, -0.19667608,\n        0.15120137, -0.00385644,  0.00753772, -0.02404735, -0.05770152,\n       -0.05576235,  0.04284578,  0.19223195, -0.30365785,  0.1860247 ,\n        0.19586145, -0.0185318 ,  0.12365689,  0.0298934 ,  0.02929932,\n        0.01904982, -0.04539383, -0.22073671, -0.10032675, -0.00897618,\n       -0.04167913, -0.02422201,  0.04328578]), 'Jack Ma': array([-0.06948743,  0.05258354, -0.00257433, -0.08774024, -0.03892684,\n       -0.10477985, -0.01715049, -0.16630766,  0.11163412, -0.08307658,\n        0.19136724, -0.00647812, -0.18188998, -0.09218571,  0.0 ...

# %%
import numpy as np
import json

# Assuming reference_face_descriptor is already computed
reference_face_descriptor = np.array(avg_descriptor)

# Convert to list and write to file
path = r"C:\Users\marus\Desktop\face_det\model.txt"
with open(path, 'w') as file:
    json.dump(reference_face_descriptor.tolist(), file)
    print('Data written successfully.')
# Out:
# Data written successfully.

# %%
# Read the descriptor from file and convert back to numpy array
with open(path, 'r') as file:
    reference_face_descriptor = np.array(json.load(file))
    print('Data read successfully.')

print(reference_face_descriptor)
# Out:
# Data read successfully.
# [-0.06199548  0.19504727  0.04265369 -0.00892971 -0.14164174  0.09158545
#  -0.00862234 -0.03430767  0.19341645 -0.07911845  0.24756078  0.02611138
#  -0.2068126  -0.05420454 -0.10649706  0.09112601 -0.16052324 -0.0839812
#  -0.1357447  -0.09713077  0.03867843  0.08602964 -0.04533256  0.01084165
#  -0.23742991 -0.26860009 -0.00166699 -0.0890206   0.06064136 -0.18782841
#         -0.03506226,  0.24814296,  0.04682871, -0.02695411,  0.04588499,
#         -0.00783588, -0.16522206,  0.01359724, -0.10066255, -0.02784994,
#          0.11100293, -0.1046268 , -0.02573991,  0.11042321, -0.17752981,
#          0.20569249, -0.05116514,  0.0094033 , -0.01911435, -0.06891774,
#         -0.11345952,  0.11247657,  0.22162947, -0.25074229,  0.20744153,
#          0.07004848, -0.01001174,  0.14833835,  0.12713157,  0.01266929,
#         -0.04140763, -0.02913497, -0.1127991 , -0.12390762,  0.09870855,
#         -0.09868602,  0.06746685, -0.04369179])}

# %%
import dlib
import cv2
import numpy as np
import os
import face_recognition

# Load model paths (replace with your actual paths)
file_path = r"C:\Users\marus\Desktop\face_det\shape_predictor_68_face_landmarks.dat"
file2_path = r"C:\Users\marus\Desktop\face_det\dlib_face_recognition_resnet_model_v1.dat"

# Load reference face descriptors (modify this section)
known_faces_dir = r"C:\Users\marus\Desktop\face_det\images"  # Directory containing known faces
known_face_names = []
known_face_encodings = []

for person_dir in os.listdir(known_faces_dir):
    person_path = os.path.join(known_faces_dir, person_dir)
    if os.path.isdir(person_path):
        for filename in os.listdir(person_path):
            if filename.endswith(".jpg") or filename.endswith(".png"):  # Adjust for other image formats
                image_path = os.path.join(person_path, filename)
                known_face_image = face_recognition.load_image_file(image_path)
                known_face_encoding = face_recognition.face_encodings(known_face_image)[0]

                # Use directory name as the person's name
                known_face_names.append(person_dir)
                known_face_encodings.append(known_face_encoding)

# Initialize detectors and video capture
detector = dlib.get_frontal_face_detector()
sp = dlib.shape_predictor(file_path)
facerec = dlib.face_recognition_model_v1(file2_path)

video_path = r"C:\Users\marus\Desktop\face_det\videos\ilon_video.mp4"  # Replace with your video path
cap = cv2.VideoCapture(video_path)

# Define the desired frame width and height (720p)
frame_width = 720
frame_height = 720

while True:
    ret, frame = cap.read()
    if not ret:
        break

    # ret, frame = cap.read()
    # if not ret:
    #     break

    # frame_count += 1
    # if frame_count % skip_frames != 0:
    #     continue


    # Resize the frame to 720p while maintaining the aspect ratio
    height, width, _ = frame.shape
    scaling_factor = min(frame_width / width, frame_height / height)
    new_width = int(width * scaling_factor)
    new_height = int(height * scaling_factor)
    resized_frame = cv2.resize(frame, (new_width, new_height))

    # Convert frame to grayscale for face detection
    gray_frame = cv2.cvtColor(resized_frame, cv2.COLOR_BGR2GRAY)
    faces = detector(gray_frame, 1)

    # Convert dlib rectangles to the format that face_recognition expects
    face_locations = [(face.top(), face.right(), face.bottom(), face.left()) for face in faces]

    # Loop through detected faces
    for face_location, face_encoding in zip(face_locations, face_recognition.face_encodings(resized_frame, face_locations)):
        matches = face_recognition.compare_faces(known_face_encodings, face_encoding)
        name = "Unknown"

        # If a match is found, get the name from the known faces list
        if True in matches:
            first_match_index = matches.index(True)
            name = known_face_names[first_match_index]

        # Display bounding box and name
        top, right, bottom, left = face_location
        cv2.rectangle(resized_frame, (left, top), (right, bottom), (0, 0, 255), 2)
        cv2.putText(resized_frame, name, (left + 6, bottom - 6), cv2.FONT_HERSHEY_DUPLEX, 1.0, (255, 255, 255), 1)

    cv2.imshow('Video', resized_frame)

    # Exit on 'q' key press
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
